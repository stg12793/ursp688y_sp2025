# %% [markdown]
# Urban Data Science & Smart Cities <br>
# URSP688Y Spring 2025<br>
# Instructor: Chester Harvey <br>
# Urban Studies & Planning <br>
# National Center for Smart Growth <br>
# University of Maryland

# %% [markdown]
# # Exercise02

# %%
import pandas as pd

# %%
df = pd.read_csv('District_Court_of_Maryland_Eviction_Case_Data_MG_PG.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Event Date                                         Event Type  \
# 0           0  01/03/2023  Warrant of Restitution - Return of Service - E...
# 1           1  01/03/2023  Warrant of Restitution - Return of Service - E...
# 2           2  01/03/2023  Warrant of Restitution - Return of Service - E...
# 3           3  01/03/2023  Warrant of Restitution - Return of Service - E...
# 4           4  01/03/2023  Warrant of Restitution - Return of Service - E...
#
#   Event Comment      County   Location    Tenant City Tenant State  \
# 0           NaN  Montgomery  Rockville  Silver Spring           MD
# 1           NaN  Montgomery  Rockville  Silver Spring           MD
# 2           NaN  Montgomery  Rockville       Bethesda           MD
# 3           NaN  Montgomery  Rockville  Silver Spring           MD
# 4           NaN  Montgomery  Rockville      Rockville           MD
#
#    Tenant ZIP Code            Case Type         Case Number Evicted Date  \
# ...

# %% [markdown]
# ## Problem
# A law passed in 2022 requires the District Court of Maryland to collect and distribute records of court filings for evictions. These data, *without* precise street addresses to protect tenant privacy, are available to download as a CSV table from the [Maryland Open Data Portal](https://opendata.maryland.gov/Housing/District-Court-of-Maryland-Eviction-Case-Data/mvqb-b4hf/about_data).
#
# The eviction process is complicated and produces messy data. Some fields in this table are structured with standard categories; others are not. Some eviction cases are documented by multiple "events" that sequentially record an initial filing and then a cancellation, eviction, or expiration (see the `Event Type` column). Other cases have multiple of the same type of event, or have only a single event. These may be recording errors, they may indicate that a case is outstanding, or that a follow-up event was simply never recorded. Unfortunatly, these types of internal inconsistencies are all too common in data about cities that are generated with imperfect, often manual systems, with little documentation about the definitions of columns or values, especially null values (I can't find a data dictionary or other official documentation for this table. Can you?). Data like these can also include entirely unstructured fields, such as `Event Comment`, which contain rich additional information but must be creatively parsed to use them.
#
# Your task for this exercise is to "wrangle" these data to answer
#
#
# - First, write a function that takes the raw table as an input—-you can decide whether the argument to the function is a path to the CSV or a Pandas DataFrame into which you have already the CSV--and cleans it up into a tidy dataframe that is easy to use for this and future analyses. You can imagine using this function as a handy pre-processor whenever you download an updated copy of the eviction data.
#     - Consider changing the names of columns so they're intuitive and easy to access
#     - Consider changing the data types of columns so they are easy to sort and query (e.g., change dates stored as strings to Pandas datetimes, or change whole numbers stored as floats to integers).
#     -
#
#
#
#
# ## Data
#
# Below is a dictionary with a few hundred records of service requests from a dataset available on Montgomery County's [Open Data Portal](https://data.montgomerycountymd.gov/Community-Recreation/Agency-Service-Requests/5diu-yj9e/about_data). I filtered the raw data to requests made so-far in 2025, did small amount of cleaning to exclude records with irregular structures, and stored the results in a dictionary so you can access it easily. In a couple weeks, we'll be working with more advanced tools and you'll be able to import the whole raw dataset as a table. For now, please just use this sample dictionary. Believe it or not, even huge raw datasets used widely by data scientists are often stored in dictionary-like formats, so it's a very common structure to work with. We'll see more about that in a few weeks, too.
#
# As you can see, the County got a lot of requests in less than a month!
#
# ## Hints
# - There are many possible ways to program this. don't worry about finding the "right" or "best" one. Figure out one way that works, and then refine it if you see opportunities.
# - `for` loops may be useful for iterating through lists and dictionaries.
# - You may want to define one or more variables and update them on each loop to keep track of counts or things your has 'seen' in the data.
# - `service_requests` is a list with dictionaries nested inside it--a list of dictionaries.
# - To access the dictionaries inside the list, you may want to use nested loops: one loop inside another loop.
#
# ## File Management and Submitting
# 1. In GitHub Desktop, **make a branch** in your fork of the course respository. Give the branch a name that will help you keep track of what you will commit to it (e.g., "exercise2"). [Here's some documentation about managing branches in GitHub Desktop](https://docs.github.com/en/desktop/making-changes-in-a-branch/managing-branches-in-github-desktop)
# 2. Switch to your new branch. If you already started working on Exercise 2, you can choose the option to bring changes to the new branch.
# 3. Save a copy of the exercise notebook with your first name as an underscored suffix (e.g., `exercise02_chester.ipynb`)
# 4. Commit and push your saved notebook to your branch.
# 5. Make sure that the only files
# 6. Make a pull request from your branch.

# %%
# Write your program here
